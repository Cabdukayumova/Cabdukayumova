# %% [markdown]
# <a href="https://colab.research.google.com/github/Cabdukayumova/ML-DL/blob/main/YOLOv5_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div align="center">
#
#   <a href="https://ultralytics.com/yolov5" target="_blank">
#     <img width="1024", src="https://github.com/ultralytics/assets/raw/master/yolov5/v62/splash_notebook.png"></a>
#
#
# <br>
#   <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#   <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# <br>
#
# This <a href="https://github.com/ultralytics/yolov5">YOLOv5</a> 🚀 notebook by <a href="https://ultralytics.com">Ultralytics</a> presents simple train, validate and predict examples to help start your AI adventure.<br>See <a href="https://github.com/ultralytics/yolov5/issues/new/choose">GitHub</a> for community support or <a href="https://ultralytics.com/contact">contact us</a> for professional support.
#
# </div>

# %% [markdown]
# # Setup
#
# Clone GitHub [repository](https://github.com/ultralytics/yolov5), install [dependencies](https://github.com/ultralytics/yolov5/blob/master/requirements.txt) and check PyTorch and GPU.

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.2-125-g6a9fffd Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 37.4/78.2 GB disk)

# %%
# !unzip -q /content/train_data.zip -d ../

# %% [markdown]
# # 1. Detect
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# ```shell
# python detect.py --source 0  # webcam
#                           img.jpg  # image
#                           vid.mp4  # video
#                           path/  # directory
#                           'path/*.jpg'  # glob
#                           'https://youtu.be/Zgi9g1ksQHc'  # YouTube
#                           'rtsp://example.com/media.mp4'  # RTSP, RTMP, HTTP stream
# ```

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# detect: weights=['yolov5s.pt'], source=data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.2-56-g30e674b Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.2/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 27.8MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/2 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 14.8ms
# image 2/2 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 20.1ms
# Speed: 0.6ms pre-process, 17.4ms inference, 21.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# <img align="left" src="https://user-images.githubusercontent.com/26833433/127574988-6a558aa1-d268-44b9-bf6b-62d4c605cc72.jpg" width="600">

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on the [COCO](https://cocodataset.org/#home) dataset's `val` or `test` splits. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag.

# %%
# Download COCO val
torch.hub.download_url_to_file('https://ultralytics.com/assets/coco2017val.zip', 'tmp.zip')  # download (780M - 5000 images)
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip  # unzip
# Out:
#   0%|          | 0.00/780M [00:00<?, ?B/s]

# %%
# Validate YOLOv5s on COCO val
# !python val.py --weights yolov5s.pt --data coco.yaml --img 640 --half
# Out:
# val: data=/content/yolov5/data/coco.yaml, weights=['yolov5s.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=True, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v6.2-56-g30e674b Python-3.7.13 torch-1.12.1+cu113 CUDA:0 (Tesla V100-SXM2-16GB, 16160MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 52.7MB/s]
# val: Scanning '/content/datasets/coco/val2017' images and labels...4952 found, 48 missing, 0 empty, 0 corrupt: 100% 5000/5000 [00:00<00:00, 10509.20it/s]
# val: New cache created: /content/datasets/coco/val2017.cache
#                  Class     Images  Instances          P          R     mAP@.5 mAP@.5:.95: 100% 157/157 [00:50<00:00,  3.10it/s]
#                    all       5000      36335       0.67      0.521      0.566      0.371
# Speed: 0.1ms pre-process, 1.0ms inference, 1.5ms NMS per image at shape (32, 3, 640, 640)
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5s_predictions.json...
# loading annotations into memory...
# Done (t=0.81s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=5.62s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=77.03s).
# Accumulating evaluation results...
# DONE (t=14.63s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.374
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.572
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.402
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.423
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.489
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.311
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.516
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.566
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.378
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.625
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.724
# Results saved to runs/val/exp

# %% [markdown]
# # 3. Train
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="1000" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/615627e5824c9c6195abfda9_computer-vision-cycle.png"/></a></p>
# Close the active learning loop by sampling images from your inference conditions with the `roboflow` pip package
# <br><br>
#
# Train a YOLOv5s model on the [COCO128](https://www.kaggle.com/ultralytics/coco128) dataset with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`.
#
# - **Pretrained [Models](https://github.com/ultralytics/yolov5/tree/master/models)** are downloaded
# automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases)
# - **[Datasets](https://github.com/ultralytics/yolov5/tree/master/data)** available for autodownload include: [COCO](https://github.com/ultralytics/yolov5/blob/master/data/coco.yaml), [COCO128](https://github.com/ultralytics/yolov5/blob/master/data/coco128.yaml), [VOC](https://github.com/ultralytics/yolov5/blob/master/data/VOC.yaml), [Argoverse](https://github.com/ultralytics/yolov5/blob/master/data/Argoverse.yaml), [VisDrone](https://github.com/ultralytics/yolov5/blob/master/data/VisDrone.yaml), [GlobalWheat](https://github.com/ultralytics/yolov5/blob/master/data/GlobalWheat2020.yaml), [xView](https://github.com/ultralytics/yolov5/blob/master/data/xView.yaml), [Objects365](https://github.com/ultralytics/yolov5/blob/master/data/Objects365.yaml), [SKU-110K](https://github.com/ultralytics/yolov5/blob/master/data/SKU-110K.yaml).
# - **Training Results** are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.
# <br><br>
#
# A **Mosaic Dataloader** is used for training which combines 4 images into 1 mosaic.
#
# ## Train on Custom Data with Roboflow 🌟 NEW
#
# [Roboflow](https://roboflow.com/?ref=ultralytics) enables you to easily **organize, label, and prepare** a high quality dataset with your own custom data. Roboflow also makes it easy to establish an active learning pipeline, collaborate with your team on dataset improvement, and integrate directly into your model building workflow with the `roboflow` pip package.
#
# - Custom Training Example: [https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/](https://blog.roboflow.com/how-to-train-yolov5-on-a-custom-dataset/?ref=ultralytics)
# - Custom Training Notebook: [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/roboflow-ai/yolov5-custom-training-tutorial/blob/main/yolov5-custom-training.ipynb)
# <br>
#
# <p align=""><a href="https://roboflow.com/?ref=ultralytics"><img width="480" src="https://uploads-ssl.webflow.com/5f6bc60e665f54545a1e52a5/6152a275ad4b4ac20cd2e21a_roboflow-annotate.gif"/></a></p>Label images lightning fast (including with model-assisted labeling)

# %%
#@title Select YOLOv5 🚀 logger {run: 'auto'}
logger = 'TensorBoard' #@param ['TensorBoard', 'Comet', 'ClearML', 'W&B']

if logger == 'TensorBoard':
  # %load_ext tensorboard
  # %tensorboard --logdir runs/train
elif logger == 'Comet':
  # %pip install -q comet_ml
  import comet_ml; comet_ml.init()
elif logger == 'ClearML':
  # %pip install -q clearml && clearml-init
elif logger == 'W&B':
  # %pip install -q wandb
  import wandb; wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 1000 --data /content/yolov5/data/custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1000, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-125-g6a9fffd Python-3.7.14 torch-1.12.1+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs in Weights & Biases
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://github.com/ultralytics/yolov5/releases/download/v6.2/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 213MB/s]
#
# Overriding model.yaml nc=80 with nc=3
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     21576  models.yolo.Detect                      [3, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7027720 parameters, 7027720 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning '/content/train_data/labels/train' images and labels...60 found, 0 missing, 0 empty, 0 corrupt: 100% 60/60 [00:00<00:00, 2106.07it/s]
# train: New cache created: /content/train_data/labels/train.cache
# train: Caching images (0.1GB ram): 100% 60/60 [00:00<00:00, 210.05it/s]
# val: Scanning '/content/train_data/labels/val' images and labels...30 found, 0 missing, 0 empty, 0 corrupt: 100% 30/30 [00:00<00:00, 1333.29it/s]
# val: New cache created: /content/train_data/labels/val.cache
# val: Caching images (0.0GB ram): 100% 30/30 [00:00<00:00, 60.28it/s]
#
# AutoAnchor: 3.20 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 1000 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/999      3.74G     0.1113    0.03163    0.03868         30        640: 100% 4/4 [00:04<00:00,  1.06s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:01<00:00,  1.79s/it]
#                    all         30         30    0.00252      0.633    0.00673     0.0014
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/999      4.21G    0.09371    0.02984    0.03354         25        640: 100% 4/4 [00:00<00:00,  4.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  1.82it/s]
#                    all         30         30    0.00348        0.9     0.0136    0.00238
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/999      4.21G    0.07311    0.02897     0.0307         25        640: 100% 4/4 [00:00<00:00,  4.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  2.63it/s]
#                    all         30         30     0.0034      0.933     0.0135    0.00302
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/999      4.21G    0.07767    0.02997    0.03392         28        640: 100% 4/4 [00:00<00:00,  4.46it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.26it/s]
#                    all         30         30    0.00342      0.967     0.0125    0.00273
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/999      4.21G    0.07701    0.03038    0.03192         35        640: 100% 4/4 [00:00<00:00,  4.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.38it/s]
#                    all         30         30    0.00348      0.967      0.017    0.00387
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/999      4.21G    0.05967    0.02941    0.02756         32        640: 100% 4/4 [00:00<00:00,  4.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all         30         30    0.00335      0.967     0.0202    0.00591
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/999      4.21G    0.06573    0.02955    0.03119         21        640: 100% 4/4 [00:00<00:00,  4.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.62it/s]
#                    all         30         30    0.00339          1     0.0635     0.0177
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/999      4.21G    0.06237    0.02865     0.0362         28        640: 100% 4/4 [00:00<00:00,  4.83it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.57it/s]
#                    all         30         30    0.00336          1      0.209     0.0684
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/999      4.21G    0.05935    0.02901    0.03351         26        640: 100% 4/4 [00:00<00:00,  4.83it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.71it/s]
#                    all         30         30      0.159      0.633      0.336      0.112
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/999      4.21G    0.05638    0.02619    0.03007         26        640: 100% 4/4 [00:00<00:00,  4.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.09it/s]
#                    all         30         30      0.231      0.225      0.364      0.122
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/999      4.21G    0.06147    0.02702     0.0306         27        640: 100% 4/4 [00:00<00:00,  4.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.07it/s]
#                    all         30         30      0.832        0.3      0.378      0.196
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/999      4.21G    0.06351    0.02695    0.03575         24        640: 100% 4/4 [00:00<00:00,  4.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.05it/s]
#                    all         30         30      0.913      0.333      0.432      0.204
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/999      4.21G    0.04197    0.02265    0.02221         22        640: 100% 4/4 [00:00<00:00,  4.84it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.14it/s]
#                    all         30         30      0.451      0.367      0.443      0.192
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/999      4.21G    0.05199    0.02548    0.03183         31        640: 100% 4/4 [00:00<00:00,  4.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.17it/s]
#                    all         30         30      0.914      0.289      0.353      0.135
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/999      4.21G     0.0452    0.02428    0.02225         30        640: 100% 4/4 [00:00<00:00,  4.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.12it/s]
#                    all         30         30       0.76      0.367       0.44       0.23
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/999      4.21G    0.04691    0.02282    0.02539         32        640: 100% 4/4 [00:00<00:00,  4.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.36it/s]
#                    all         30         30      0.987      0.267      0.477      0.282
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/999      4.21G    0.05841    0.02026    0.02983         20        640: 100% 4/4 [00:00<00:00,  4.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.54it/s]
#                    all         30         30      0.333      0.651       0.63      0.248
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/999      4.21G    0.04298    0.02015     0.0188         25        640: 100% 4/4 [00:00<00:00,  4.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.62it/s]
#                    all         30         30      0.196      0.563       0.24     0.0581
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/999      4.21G    0.06088    0.01705    0.02612         29        640: 100% 4/4 [00:00<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.66it/s]
#                    all         30         30      0.435      0.567      0.518       0.21
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/999      4.21G    0.04158    0.01837    0.01972         24        640: 100% 4/4 [00:00<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.41it/s]
#                    all         30         30      0.267      0.467      0.368      0.182
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/999      4.21G    0.05289    0.01916    0.02932         32        640: 100% 4/4 [00:00<00:00,  4.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.37it/s]
#                    all         30         30      0.561      0.694      0.646      0.327
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/999      4.21G    0.04588    0.01971    0.02184         29        640: 100% 4/4 [00:00<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.84it/s]
#                    all         30         30      0.421      0.833      0.577      0.258
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/999      4.21G     0.0556    0.01707    0.02146         28        640: 100% 4/4 [00:00<00:00,  4.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.54it/s]
#                    all         30         30      0.507      0.601      0.645      0.375
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/999      4.21G    0.04891    0.02016    0.02257         29        640: 100% 4/4 [00:00<00:00,  4.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.83it/s]
#                    all         30         30      0.449      0.698       0.64        0.3
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/999      4.21G    0.04974    0.01622    0.02102         24        640: 100% 4/4 [00:00<00:00,  4.52it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.79it/s]
#                    all         30         30      0.272      0.867      0.643       0.35
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/999      4.21G    0.04626     0.0175    0.01608         38        640: 100% 4/4 [00:00<00:00,  4.83it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.55it/s]
#                    all         30         30      0.377      0.633      0.637      0.242
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/999      4.21G    0.05625     0.0147    0.01969         29        640: 100% 4/4 [00:00<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.79it/s]
#                    all         30         30      0.575      0.733      0.784       0.33
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/999      4.21G    0.04481    0.01711    0.01966         27        640: 100% 4/4 [00:00<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.35it/s]
#                    all         30         30      0.648        0.8      0.842      0.333
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/999      4.21G    0.05037     0.0175    0.02184         27        640: 100% 4/4 [00:00<00:00,  4.97it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.39it/s]
#                    all         30         30      0.769      0.763      0.861      0.481
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/999      4.21G    0.04527    0.01544    0.01784         26        640: 100% 4/4 [00:00<00:00,  4.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.03it/s]
#                    all         30         30      0.545      0.856      0.816      0.343
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/999      4.21G     0.0478    0.01554    0.01708         29        640: 100% 4/4 [00:00<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.76it/s]
#                    all         30         30      0.822      0.757      0.925      0.609
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/999      4.21G    0.04072    0.01414    0.01758         30        640: 100% 4/4 [00:00<00:00,  4.58it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.09it/s]
#                    all         30         30      0.719       0.83      0.812      0.289
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/999      4.21G    0.04173    0.01434    0.01548         25        640: 100% 4/4 [00:00<00:00,  4.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.74it/s]
#                    all         30         30      0.777      0.745      0.818      0.391
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/999      4.21G    0.05106    0.01359    0.01429         19        640: 100% 4/4 [00:00<00:00,  4.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.81it/s]
#                    all         30         30       0.74      0.953      0.836        0.5
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/999      4.21G    0.04211    0.01303    0.01742         22        640: 100% 4/4 [00:00<00:00,  4.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.86it/s]
#                    all         30         30      0.721      0.954      0.829      0.464
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/999      4.21G    0.03509    0.01575    0.01922         24        640: 100% 4/4 [00:00<00:00,  5.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.66it/s]
#                    all         30         30      0.519      0.811      0.791      0.415
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/999      4.21G    0.04123    0.01368    0.01321         27        640: 100% 4/4 [00:00<00:00,  4.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.00it/s]
#                    all         30         30      0.767      0.933      0.891       0.35
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/999      4.21G    0.04364     0.0128    0.02139         24        640: 100% 4/4 [00:00<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.82it/s]
#                    all         30         30      0.519      0.833      0.828      0.387
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/999      4.21G     0.0451    0.01289    0.01498         26        640: 100% 4/4 [00:00<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.96it/s]
#                    all         30         30      0.597      0.791      0.767      0.388
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/999      4.21G    0.04485    0.01165     0.0103         32        640: 100% 4/4 [00:00<00:00,  4.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.62it/s]
#                    all         30         30      0.719      0.798      0.784      0.305
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/999      4.21G    0.04759    0.01387    0.01748         27        640: 100% 4/4 [00:00<00:00,  4.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.90it/s]
#                    all         30         30      0.644      0.751      0.765       0.51
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/999      4.21G    0.04951    0.01257    0.01178         31        640: 100% 4/4 [00:00<00:00,  4.97it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.29it/s]
#                    all         30         30      0.707      0.675      0.772      0.478
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/999      4.21G    0.05046    0.01346    0.01358         32        640: 100% 4/4 [00:00<00:00,  4.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.63it/s]
#                    all         30         30      0.625      0.703      0.683      0.389
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/999      4.21G    0.05848    0.01426    0.02242         27        640: 100% 4/4 [00:00<00:00,  4.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.66it/s]
#                    all         30         30      0.714       0.79      0.806      0.496
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/999      4.21G    0.04941    0.01351    0.02035         27        640: 100% 4/4 [00:00<00:00,  4.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.79it/s]
#                    all         30         30      0.594      0.867      0.733      0.456
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/999      4.21G    0.04407    0.01261   0.007242         31        640: 100% 4/4 [00:00<00:00,  5.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.39it/s]
#                    all         30         30      0.755      0.898      0.807        0.4
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/999      4.21G    0.06263    0.01428    0.02059         33        640: 100% 4/4 [00:00<00:00,  4.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.95it/s]
#                    all         30         30      0.818      0.664      0.853      0.435
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/999      4.21G    0.03701    0.01315    0.01164         31        640: 100% 4/4 [00:00<00:00,  4.94it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.23it/s]
#                    all         30         30      0.645      0.751      0.681      0.405
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/999      4.21G    0.03834    0.01159   0.009368         25        640: 100% 4/4 [00:00<00:00,  5.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.02it/s]
#                    all         30         30      0.818      0.776      0.907      0.537
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/999      4.21G    0.03196    0.01252    0.01269         26        640: 100% 4/4 [00:00<00:00,  4.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.96it/s]
#                    all         30         30      0.839      0.809      0.948      0.547
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/999      4.21G    0.03603    0.01137   0.009944         23        640: 100% 4/4 [00:00<00:00,  4.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.99it/s]
#                    all         30         30      0.898      0.888      0.969      0.491
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/999      4.21G    0.04103    0.01246    0.01009         23        640: 100% 4/4 [00:00<00:00,  5.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.98it/s]
#                    all         30         30      0.801      0.882        0.9      0.586
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/999      4.21G    0.04283    0.01197    0.03492         28        640: 100% 4/4 [00:00<00:00,  4.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.93it/s]
#                    all         30         30      0.982      0.977      0.995      0.701
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/999      4.21G     0.0395    0.01197    0.01477         29        640: 100% 4/4 [00:00<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.75it/s]
#                    all         30         30       0.75      0.967      0.957      0.488
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/999      4.21G     0.0456    0.01211    0.01284         29        640: 100% 4/4 [00:00<00:00,  4.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.69it/s]
#                    all         30         30      0.925      0.948      0.956      0.677
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/999      4.21G    0.04552    0.01095    0.01317         20        640: 100% 4/4 [00:00<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.95it/s]
#                    all         30         30       0.76      0.933      0.964      0.591
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/999      4.21G    0.03671    0.01149    0.01001         23        640: 100% 4/4 [00:00<00:00,  4.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.70it/s]
#                    all         30         30      0.677      0.967      0.896      0.431
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/999      4.21G     0.0534    0.01178    0.01227         28        640: 100% 4/4 [00:00<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.62it/s]
#                    all         30         30      0.668      0.877      0.825       0.49
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/999      4.21G    0.04107     0.0119   0.009851         27        640: 100% 4/4 [00:00<00:00,  4.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.82it/s]
#                    all         30         30      0.796      0.961      0.895      0.598
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/999      4.21G    0.02852    0.01194   0.009237         17        640: 100% 4/4 [00:00<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.84it/s]
#                    all         30         30      0.791      0.915      0.899      0.477
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/999      4.21G    0.04487    0.01249    0.01331         24        640: 100% 4/4 [00:00<00:00,  4.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.98it/s]
#                    all         30         30      0.959      0.993      0.992      0.559
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/999      4.21G     0.0358    0.01052   0.005921         25        640: 100% 4/4 [00:00<00:00,  5.01it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.58it/s]
#                    all         30         30      0.719       0.82      0.911      0.394
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/999      4.21G    0.04013   0.009853   0.007539         28        640: 100% 4/4 [00:00<00:00,  4.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.74it/s]
#                    all         30         30      0.866      0.907      0.934      0.517
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/999      4.21G     0.0486    0.01261    0.01626         28        640: 100% 4/4 [00:00<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.58it/s]
#                    all         30         30       0.67      0.953      0.908      0.585
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      64/999      4.21G     0.0367    0.01225    0.01446         34        640: 100% 4/4 [00:00<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.55it/s]
#                    all         30         30      0.778      0.995      0.894      0.391
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      65/999      4.21G    0.03069    0.01259   0.008345         32        640: 100% 4/4 [00:00<00:00,  4.58it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.73it/s]
#                    all         30         30      0.531      0.964      0.843      0.532
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      66/999      4.21G    0.04385    0.01171   0.008838         24        640: 100% 4/4 [00:00<00:00,  4.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.63it/s]
#                    all         30         30      0.813      0.971      0.992      0.656
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      67/999      4.21G    0.02923    0.01048   0.006287         24        640: 100% 4/4 [00:00<00:00,  4.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.10it/s]
#                    all         30         30      0.767      0.972      0.967      0.589
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      68/999      4.21G    0.03505     0.0108   0.005706         30        640: 100% 4/4 [00:00<00:00,  4.58it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.90it/s]
#                    all         30         30      0.758      0.931       0.96      0.574
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      69/999      4.21G    0.03376    0.01048   0.008033         25        640: 100% 4/4 [00:00<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.75it/s]
#                    all         30         30      0.831      0.944      0.977      0.638
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      70/999      4.21G    0.03787   0.009941   0.009253         18        640: 100% 4/4 [00:00<00:00,  4.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.60it/s]
#                    all         30         30      0.851      0.918      0.931       0.59
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      71/999      4.21G    0.04843    0.01179     0.0143         26        640: 100% 4/4 [00:00<00:00,  4.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.30it/s]
#                    all         30         30      0.857      0.933      0.974      0.622
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      72/999      4.21G    0.04588      0.011    0.01149         26        640: 100% 4/4 [00:00<00:00,  4.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.86it/s]
#                    all         30         30      0.954      0.954      0.995      0.692
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      73/999      4.21G    0.03121    0.01011    0.00816         28        640: 100% 4/4 [00:00<00:00,  4.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.89it/s]
#                    all         30         30       0.92      0.898       0.98      0.728
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      74/999      4.21G    0.02877   0.009663    0.00657         31        640: 100% 4/4 [00:00<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.74it/s]
#                    all         30         30      0.864      0.938      0.983      0.665
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      75/999      4.21G    0.04416    0.01063    0.01097         32        640: 100% 4/4 [00:00<00:00,  4.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.57it/s]
#                    all         30         30      0.856      0.767      0.901      0.553
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      76/999      4.21G    0.03552    0.00839   0.005506         22        640: 100% 4/4 [00:00<00:00,  4.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.44it/s]
#                    all         30         30       0.87      0.904      0.986      0.593
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      77/999      4.21G    0.03035    0.01003   0.009437         22        640: 100% 4/4 [00:00<00:00,  4.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.64it/s]
#                    all         30         30      0.855      0.865      0.944      0.643
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      78/999      4.21G     0.0303    0.01007   0.005207         28        640: 100% 4/4 [00:00<00:00,  4.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.58it/s]
#                    all         30         30      0.842          1      0.977      0.663
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      79/999      4.21G      0.024    0.01007     0.0043         26        640: 100% 4/4 [00:00<00:00,  4.97it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.86it/s]
#                    all         30         30      0.899      0.904      0.995      0.656
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      80/999      4.21G    0.03942    0.01069   0.006533         29        640: 100% 4/4 [00:00<00:00,  4.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.61it/s]
#                    all         30         30      0.957          1      0.995      0.699
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      81/999      4.21G    0.02968   0.009599   0.008698         30        640: 100% 4/4 [00:00<00:00,  4.72it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.38it/s]
#                    all         30         30      0.899          1      0.995       0.61
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      82/999      4.21G    0.04332   0.009552    0.01166         24        640: 100% 4/4 [00:00<00:00,  4.69it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.77it/s]
#                    all         30         30      0.967          1      0.995       0.63
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      83/999      4.21G    0.02134   0.009024   0.004594         32        640: 100% 4/4 [00:00<00:00,  4.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.09it/s]
#                    all         30         30       0.91          1      0.995      0.539
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      84/999      4.21G    0.03862     0.0113    0.01836         28        640: 100% 4/4 [00:00<00:00,  4.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.76it/s]
#                    all         30         30      0.991          1      0.995      0.719
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      85/999      4.21G    0.02367    0.01039   0.006064         25        640: 100% 4/4 [00:00<00:00,  4.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.94it/s]
#                    all         30         30      0.937      0.986      0.989       0.72
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      86/999      4.21G    0.03806     0.0117    0.01385         24        640: 100% 4/4 [00:00<00:00,  4.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.88it/s]
#                    all         30         30      0.993      0.993      0.995        0.7
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      87/999      4.21G    0.05055    0.01122     0.0139         35        640: 100% 4/4 [00:00<00:00,  4.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.26it/s]
#                    all         30         30      0.961      0.985      0.995      0.648
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      88/999      4.21G    0.03043    0.00931    0.01246         28        640: 100% 4/4 [00:00<00:00,  5.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.61it/s]
#                    all         30         30      0.946      0.975      0.992      0.574
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      89/999      4.21G    0.03243   0.009846     0.0146         26        640: 100% 4/4 [00:00<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.36it/s]
#                    all         30         30      0.975      0.992      0.995        0.7
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      90/999      4.21G      0.033    0.01084    0.01409         28        640: 100% 4/4 [00:00<00:00,  4.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.24it/s]
#                    all         30         30      0.974          1      0.995      0.701
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      91/999      4.21G    0.02871   0.009082   0.008981         21        640: 100% 4/4 [00:00<00:00,  4.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.80it/s]
#                    all         30         30      0.988          1      0.995      0.632
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      92/999      4.21G    0.04483   0.009701    0.01173         24        640: 100% 4/4 [00:00<00:00,  4.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.21it/s]
#                    all         30         30      0.763      0.989      0.915       0.62
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      93/999      4.21G    0.02847    0.01053   0.007708         30        640: 100% 4/4 [00:00<00:00,  4.79it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.60it/s]
#                    all         30         30      0.982          1      0.995      0.599
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      94/999      4.21G     0.0327   0.009269   0.009019         20        640: 100% 4/4 [00:00<00:00,  4.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.84it/s]
#                    all         30         30      0.977          1      0.995      0.612
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      95/999      4.21G    0.02602     0.0086   0.008437         19        640: 100% 4/4 [00:00<00:00,  4.92it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.28it/s]
#                    all         30         30       0.96      0.994      0.995      0.585
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      96/999      4.21G    0.04177    0.01137   0.007992         31        640: 100% 4/4 [00:00<00:00,  5.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.15it/s]
#                    all         30         30      0.951       0.97      0.995      0.676
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      97/999      4.21G    0.02446   0.008648   0.008915         27        640: 100% 4/4 [00:00<00:00,  4.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.58it/s]
#                    all         30         30      0.894      0.973      0.995      0.586
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      98/999      4.21G    0.03362   0.009936   0.006197         27        640: 100% 4/4 [00:00<00:00,  4.76it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.73it/s]
#                    all         30         30      0.744      0.926      0.986      0.635
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      99/999      4.21G    0.03356    0.00998   0.009518         28        640: 100% 4/4 [00:00<00:00,  4.77it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.43it/s]
#                    all         30         30      0.779      0.964      0.992      0.658
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     100/999      4.21G    0.04004    0.00997    0.01051         31        640: 100% 4/4 [00:00<00:00,  4.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.55it/s]
#                    all         30         30      0.865          1      0.995      0.717
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     101/999      4.21G    0.01873   0.009502   0.008166         27        640: 100% 4/4 [00:00<00:00,  4.64it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.85it/s]
#                    all         30         30      0.865      0.987      0.995      0.613
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     102/999      4.21G    0.02951   0.008315   0.009401         22        640: 100% 4/4 [00:00<00:00,  4.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.98it/s]
#                    all         30         30       0.87      0.993      0.995       0.69
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     103/999      4.21G    0.02563    0.01006   0.007529         30        640: 100% 4/4 [00:00<00:00,  4.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.60it/s]
#                    all         30         30       0.88      0.988      0.995       0.68
#
# ...
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.86it/s]
#                    all         30         30      0.992          1      0.995      0.823
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     408/999      4.21G     0.0137   0.007488   0.001506         34        640: 100% 4/4 [00:00<00:00,  4.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  5.00it/s]
#                    all         30         30      0.991          1      0.995      0.791
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     409/999      4.21G    0.01879   0.006159   0.006629         24        640: 100% 4/4 [00:00<00:00,  4.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.95it/s]
#                    all         30         30      0.991          1      0.995      0.806
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     410/999      4.21G    0.02422   0.007351   0.002348         28        640: 100% 4/4 [00:00<00:00,  4.62it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.85it/s]
#                    all         30         30      0.991          1      0.995      0.804
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     411/999      4.21G    0.01801   0.006868   0.002189         28        640: 100% 4/4 [00:00<00:00,  4.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.58it/s]
#                    all         30         30      0.992          1      0.995      0.805
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     412/999      4.21G    0.01843   0.008176   0.002119         32        640: 100% 4/4 [00:00<00:00,  4.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.44it/s]
#                    all         30         30      0.992          1      0.995      0.807
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     413/999      4.21G    0.02078   0.007245   0.002404         23        640: 100% 4/4 [00:00<00:00,  4.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.85it/s]
#                    all         30         30      0.993          1      0.995      0.828
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     414/999      4.21G    0.02061   0.006531   0.002963         28        640: 100% 4/4 [00:00<00:00,  4.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.69it/s]
#                    all         30         30      0.992          1      0.995      0.841
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     415/999      4.21G    0.01783   0.007625   0.006753         28        640: 100% 4/4 [00:00<00:00,  4.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.67it/s]
#                    all         30         30      0.991          1      0.995      0.836
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     416/999      4.21G     0.0124   0.007439   0.001931         26        640: 100% 4/4 [00:00<00:00,  4.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.89it/s]
#                    all         30         30       0.99          1      0.995      0.842
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     417/999      4.21G    0.02033   0.007467   0.002547         26        640: 100% 4/4 [00:00<00:00,  4.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.67it/s]
#                    all         30         30      0.989          1      0.995      0.834
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     418/999      4.21G    0.01288   0.006166   0.001864         26        640: 100% 4/4 [00:00<00:00,  4.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.57it/s]
#                    all         30         30      0.988          1      0.995      0.839
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     419/999      4.21G    0.02055   0.006519   0.007849         21        640: 100% 4/4 [00:00<00:00,  4.51it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.48it/s]
#                    all         30         30      0.987          1      0.995      0.853
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     420/999      4.21G    0.02302   0.007711   0.002428         31        640: 100% 4/4 [00:00<00:00,  4.64it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.55it/s]
#                    all         30         30       0.99          1      0.995      0.843
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     421/999      4.21G    0.01572   0.006526   0.004629         21        640: 100% 4/4 [00:00<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.40it/s]
#                    all         30         30      0.991          1      0.995      0.843
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     422/999      4.21G    0.01231   0.006796   0.001496         17        640: 100% 4/4 [00:00<00:00,  4.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.60it/s]
#                    all         30         30      0.992          1      0.995      0.842
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     423/999      4.21G     0.0223   0.007773   0.004052         29        640: 100% 4/4 [00:00<00:00,  4.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.77it/s]
#                    all         30         30      0.992          1      0.995      0.844
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     424/999      4.21G    0.02117   0.006889    0.00544         29        640: 100% 4/4 [00:00<00:00,  4.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.85it/s]
#                    all         30         30      0.992          1      0.995      0.847
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     425/999      4.21G    0.02145    0.00801   0.004718         35        640: 100% 4/4 [00:00<00:00,  4.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.79it/s]
#                    all         30         30      0.992          1      0.995      0.843
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     426/999      4.21G    0.02134   0.007393   0.008426         33        640: 100% 4/4 [00:00<00:00,  4.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.63it/s]
#                    all         30         30      0.992          1      0.995      0.838
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     427/999      4.21G    0.02096   0.006458   0.007446         25        640: 100% 4/4 [00:00<00:00,  4.52it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.78it/s]
#                    all         30         30      0.992          1      0.995      0.839
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     428/999      4.21G     0.0177   0.006658   0.005533         28        640: 100% 4/4 [00:00<00:00,  4.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.49it/s]
#                    all         30         30       0.99          1      0.995      0.836
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     429/999      4.21G    0.02085   0.006303   0.002903         26        640: 100% 4/4 [00:00<00:00,  4.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.76it/s]
#                    all         30         30      0.988          1      0.995      0.828
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     430/999      4.21G    0.01841   0.007889    0.00176         28        640: 100% 4/4 [00:00<00:00,  4.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.95it/s]
#                    all         30         30      0.988      0.998      0.995      0.835
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     431/999      4.21G    0.01822   0.006908   0.002796         29        640: 100% 4/4 [00:00<00:00,  4.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.83it/s]
#                    all         30         30      0.988          1      0.995      0.856
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     432/999      4.21G    0.01761   0.005797    0.00313         23        640: 100% 4/4 [00:00<00:00,  4.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.43it/s]
#                    all         30         30      0.989          1      0.995       0.86
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     433/999      4.21G    0.02124   0.008075   0.005448         32        640: 100% 4/4 [00:00<00:00,  4.53it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.91it/s]
#                    all         30         30      0.986          1      0.995      0.824
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     434/999      4.21G    0.02248     0.0084   0.006972         30        640: 100% 4/4 [00:00<00:00,  4.91it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.70it/s]
#                    all         30         30      0.987          1      0.995      0.848
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     435/999      4.21G    0.01807   0.007617   0.007571         30        640: 100% 4/4 [00:00<00:00,  4.54it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.31it/s]
#                    all         30         30       0.99          1      0.995      0.854
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     436/999      4.21G    0.02334   0.006868   0.005388         24        640: 100% 4/4 [00:00<00:00,  4.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.51it/s]
#                    all         30         30      0.993          1      0.995      0.859
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     437/999      4.21G    0.01685   0.007481   0.003655         31        640: 100% 4/4 [00:00<00:00,  4.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.61it/s]
#                    all         30         30      0.992          1      0.995      0.841
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     438/999      4.21G    0.01443   0.007349    0.01107         34        640: 100% 4/4 [00:00<00:00,  4.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.72it/s]
#                    all         30         30       0.99          1      0.995      0.851
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     439/999      4.21G    0.02115   0.006964   0.007372         24        640: 100% 4/4 [00:00<00:00,  4.30it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.97it/s]
#                    all         30         30      0.991          1      0.995      0.843
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     440/999      4.21G    0.01828   0.007608   0.003048         32        640: 100% 4/4 [00:00<00:00,  4.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.90it/s]
#                    all         30         30      0.992          1      0.995      0.869
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     441/999      4.21G    0.01843   0.007398   0.002704         28        640: 100% 4/4 [00:00<00:00,  4.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.39it/s]
#                    all         30         30      0.993          1      0.995      0.849
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     442/999      4.21G    0.01885   0.007069   0.003511         24        640: 100% 4/4 [00:00<00:00,  4.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  4.30it/s]
#                    all         30         30      0.991          1      0.995      0.856
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     443/999      4.21G     0.0207   0.006654   0.002645         23        640: 100% 4/4 [00:00<00:00,  4.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.77it/s]
#                    all         30         30      0.991          1      0.995      0.815
# Stopping training early as no improvement observed in last 100 epochs. Best results observed at epoch 343, best model saved as best.pt.
# To update EarlyStopping(patience=100) pass a new patience value, i.e. `python train.py --patience 300` or use `--patience 0` to disable EarlyStopping.
#
# 444 epochs completed in 0.177 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.4MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 14.4MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 1/1 [00:00<00:00,  3.54it/s]
#                    all         30         30      0.983      0.997      0.995      0.874
#                  hello         30         10       0.97          1      0.995       0.88
#             i-love-you         30         10          1      0.992      0.995      0.832
#              thank-you         30         10      0.979          1      0.995      0.909
# Results saved to runs/train/exp

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Comet Logging and Visualization 🌟 NEW
# [Comet](https://www.comet.com/site/?ref=yolov5&utm_source=yolov5&utm_medium=affilliate&utm_campaign=yolov5_comet_integration) is now fully integrated with YOLOv5. Track and visualize model metrics in real time, save your hyperparameters, datasets, and model checkpoints, and visualize your model predictions with [Comet Custom Panels](https://www.comet.com/docs/v2/guides/comet-dashboard/code-panels/about-panels/?ref=yolov5&utm_source=yolov5&utm_medium=affilliate&utm_campaign=yolov5_comet_integration)! Comet makes sure you never lose track of your work and makes it easy to share results and collaborate across teams of all sizes!
#
# Getting started is easy:
# ```shell
# pip install comet_ml  # 1. install
# export COMET_API_KEY=<Your API Key>  # 2. paste API key
# python train.py --img 640 --epochs 3 --data coco128.yaml --weights yolov5s.pt  # 3. train
# ```
#
# To learn more about all of the supported Comet features for this integration, check out the [Comet Tutorial](https://github.com/ultralytics/yolov5/tree/master/utils/loggers/comet). If you'd like to learn more about Comet, head over to our [documentation](https://www.comet.com/docs/v2/?ref=yolov5&utm_source=yolov5&utm_medium=affilliate&utm_campaign=yolov5_comet_integration). Get started by trying out the Comet Colab Notebook:
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1RG0WOQyxlDlo5Km8GogJpIEJlg_5lyYO?usp=sharing)
#
# <img width="1920" alt="yolo-ui" src="https://user-images.githubusercontent.com/7529846/187608607-ff89c3d5-1b8b-4743-a974-9275301b0524.png">

# %% [markdown]
# ## ClearML Logging and Automation 🌟 NEW
#
# [ClearML](https://cutt.ly/yolov5-notebook-clearml) is completely integrated into YOLOv5 to track your experimentation, manage dataset versions and even remotely execute training runs. To enable ClearML (check cells above):
#
# - `pip install clearml`
# - run `clearml-init` to connect to a ClearML server (**deploy your own [open-source server](https://github.com/allegroai/clearml-server)**, or use our [free hosted server](https://cutt.ly/yolov5-notebook-clearml))
#
# You'll get all the great expected features from an experiment manager: live updates, model upload, experiment comparison etc. but ClearML also tracks uncommitted changes and installed packages for example. Thanks to that ClearML Tasks (which is what we call experiments) are also reproducible on different machines! With only 1 extra line, we can schedule a YOLOv5 training task on a queue to be executed by any number of ClearML Agents (workers).
#
# You can use ClearML Data to version your dataset and then pass it to YOLOv5 simply using its unique ID. This will help you keep track of your data without adding extra hassle. Explore the [ClearML Tutorial](https://github.com/ultralytics/yolov5/tree/master/utils/loggers/clearml) for details!
#
# <a href="https://cutt.ly/yolov5-notebook-clearml">
# <img alt="ClearML Experiment Management UI" src="https://github.com/thepycoder/clearml_screenshots/raw/main/scalars.jpg" width="1280"/></a>

# %% [markdown]
# ## Weights & Biases Logging
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <a href="https://wandb.ai/glenn-jocher/yolov5_tutorial">
# <img alt="Weights & Biases dashboard" src="https://user-images.githubusercontent.com/26833433/182482859-288a9622-4661-48db-99de-650d1dead5c6.jpg" width="1280"/></a>

# %% [markdown]
# ## Local Logging
#
# Training results are automatically logged with [Tensorboard](https://www.tensorflow.org/tensorboard) and [CSV](https://github.com/ultralytics/yolov5/pull/4148) loggers to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc.
#
# This directory contains train and val statistics, mosaics, labels, predictions and augmentated mosaics, as well as metrics and charts including precision-recall (PR) curves and confusion matrices.
#
# <img alt="Local logging results" src="https://user-images.githubusercontent.com/26833433/183222430-e1abd1b7-782c-4cde-b04d-ad52926bf818.jpg" width="1280"/>

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on macOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Additional content below for PyTorch Hub, CI, reproducing results, profiling speeds, VOC training, classification training and TensorRT example.

# %%
import torch

# PyTorch Hub Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # or yolov5n - yolov5x6, custom

# Images
img = 'https://ultralytics.com/images/zidane.jpg'  # or file, Path, PIL, OpenCV, numpy, list

# Inference
results = model(img)

# Results
results.print()  # or .show(), .save(), .crop(), .pandas(), etc.

# %%
# YOLOv5 CI
# %%shell
rm -rf runs  # remove runs/
m=yolov5n  # official weights
b=runs/train/exp/weights/best  # best.pt checkpoint
python train.py --imgsz 64 --batch 32 --weights $m.pt --cfg $m.yaml --epochs 1 --device 0  # train
for d in 0 cpu; do  # devices
  for w in $m $b; do  # weights
    python val.py --imgsz 64 --batch 32 --weights $w.pt --device $d  # val
    python detect.py --imgsz 64 --weights $w.pt --device $d  # detect
  done
done
python hubconf.py --model $m  # hub
python models/tf.py --weights $m.pt  # build TF model
python models/yolo.py --cfg $m.yaml  # build PyTorch model
python export.py --weights $m.pt --img 64 --include torchscript  # export

# %%
# Reproduce
for x in (f'yolov5{x}' for x in 'nsmlx'):
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --task speed  # speed
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# Profile
from utils.torch_utils import profile

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
results = profile(input=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# VOC
for b, m in zip([64, 64, 64, 32, 16], [f'yolov5{x}' for x in 'nsmlx']):  # batch, model
  # !python train.py --batch {b} --weights {m}.pt --data VOC.yaml --epochs 50 --img 512 --hyp hyp.VOC.yaml --project VOC --name {m} --cache

# %%
# Classification train
for m in [*(f'yolov5{x}-cls.pt' for x in 'nsmlx'), 'resnet50.pt', 'resnet101.pt', 'efficientnet_b0.pt', 'efficientnet_b1.pt']:
  for d in 'mnist', 'fashion-mnist', 'cifar10', 'cifar100', 'imagenette160', 'imagenette320', 'imagenette', 'imagewoof160', 'imagewoof320', 'imagewoof':
    # !python classify/train.py --model {m} --data {d} --epochs 10 --project YOLOv5-cls --name {m}-{d}

# %%
# Classification val
# !bash data/scripts/get_imagenet.sh --val  # download ImageNet val split (6.3G - 50000 images)
# !python classify/val.py --weights yolov5m-cls.pt --data ../datasets/imagenet --img 224  # validate

# %%
# Validate on COCO test. Zip results.json and submit to eval server at https://competitions.codalab.org/competitions/20794
# !bash data/scripts/get_coco.sh --test  # download COCO test-dev2017 (7G - 40000 images, test 20000)
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half --task test

# %%
# TensorRT 
# !pip install -U nvidia-tensorrt --index-url https://pypi.ngc.nvidia.com  # install
# !python export.py --weights yolov5s.pt --include engine --imgsz 640 --device 0  # export
# !python detect.py --weights yolov5s.engine --imgsz 640 --device 0  # inference
